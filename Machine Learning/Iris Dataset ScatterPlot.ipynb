# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt;

# %%
df=pd.read_csv('./Iris.csv')
# to specify colors 
colors={'Iris-setosa':'red','Iris-virginica':'yellow','Iris-versicolor':'green'};

# %% [markdown]
# # Scatter plots

# %%
x=df['Species'];
y=df['SepalLengthCm']
plt.scatter(x,y,c=df['Species'].map(colors));

# %%
x=df['Species'];
y=df['SepalWidthCm']
plt.scatter(x,y,c=df['Species'].map(colors));

# %%
x=df['Species'];
y=df['PetalLengthCm']
plt.scatter(x,y,c=df['Species'].map(colors));

# %%
x=df['Species'];
y=df['PetalWidthCm']
plt.scatter(x,y,c=df['Species'].map(colors));

# %%
x=df['SepalLengthCm'];
y=df['PetalLengthCm'];

plt.scatter(x,y,c=df['Species'].map(colors));

# %%
x=df['SepalWidthCm'];
y=df['PetalLengthCm']
plt.scatter(x,y,c=df['Species'].map(colors));

# %%
x=df['SepalWidthCm'];
y=df['PetalLengthCm'];

plt.scatter(x,y,c=df['Species'].map(colors));

# %%
x=df['SepalWidthCm'];
y=df['PetalWidthCm'];

plt.scatter(x,y,c=df['Species'].map(colors));

# %% [markdown]
# # Histograms

# %%
plt.hist(df['SepalLengthCm']);

# %%
plt.hist(df['SepalWidthCm']);

# %%
plt.hist(df['PetalLengthCm']);

# %%
plt.hist(df['PetalWidthCm']);

# %%
plt.hist(df['Species']);
