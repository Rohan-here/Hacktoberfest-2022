# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv('./titanic.csv');
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 324          325         0       3
# 237          238         1       2
# 427          428         1       2
# 738          739         0       3
# 66            67         1       2
# 864          865         0       2
# 631          632         0       3
# 422          423         0       3
# 875          876         1       3
# 562          563         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 324                           Sage, Mr. George John Jr    male   NaN      8
# 237                   Collyer, Miss. Marjorie "Lottie"  female   8.0      0
# 427  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
# 738                                 Ivanoff, Mr. Kanio    male   NaN      0
# 66                        Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 864                             Gill, Mr. John William    male  24.0      0
# ...

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Null values

# %%
print(df.isnull().sum());
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# * 177 rows where age is null

# %%
#fill null values in age with median

med=df['Age'].median();
df['Age'].fillna(value=med,inplace=True);
df

#fill null cabin values using bfill method.
df['Cabin'].fillna(method='bfill',inplace=True);
# drop if still null value.
df.dropna()

df['Embarked'].fillna(method='bfill',inplace=True);
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Outliers

# %%
plt.scatter(df['PassengerId'],df['Age']);

# %%
# removing outliers using z-score

mean=df['Age'].mean();
std=df['Age'].std();
print(f"mean is: {mean} and \nstd deviation is : {std}")
# Out:
# mean is: 29.36158249158249 and
# std deviation is : 13.019696550973194

# %%
print(df.shape)
z_score=(df['Age']-mean)/std;
df2=df[(z_score>3) | (z_score<(-3))];
print('Possible outliers are:');
df2
# Out:
# (891, 12)
# Possible outliers are:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare        Cabin Embarked
# 96   male  71.0      0      0    PC 17754  34.6542           A5        C
# 116  male  70.5      0      0      370369   7.7500      B58 B60        Q
# 493  male  71.0      0      0    PC 17609  49.5042          D20        C
# ...

# %%
#after removing outlier.
cleaned_df=df[(z_score<=3) & (z_score>=-3)];
cleaned_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Checking redundant data

# %%
cleaned_df.duplicated().sum()
# there is no redundant row.
# Out:
# 0
